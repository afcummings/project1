# %%
import pandas as pd
import matplotlib as plt

sugar_df2015= pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2015sugar.csv")

sugar_df2015 = sugar_df2015[["LocationAbbr", "Data_Value" ]]

sugar_df2015 = sugar_df2015.dropna()

sugar_df2017= pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv")

sugar_df2017 = sugar_df2017[["LocationAbbr", "Data_Value" ]]

sugar_df2017 = sugar_df2017.dropna()

out_of_ideas = sugar_df2015.merge(sugar_df2017, how='outer', on ='LocationAbbr')

sugar_df2013= pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2013sugar.csv")

sugar_df2013 = sugar_df2013[["LocationAbbr", "Data_Value" ]]

sugar_df2013 = sugar_df2013.dropna()

out_of_ideas = out_of_ideas.merge(sugar_df2013, how='outer', on ='LocationAbbr')

sugar_df2011= pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2011sugar.csv")

sugar_df2011 = sugar_df2011[["LocationAbbr", "Data_Value" ]]

sugar_df2011 = sugar_df2011.dropna()

out_of_ideas = out_of_ideas.merge(sugar_df2011, how='outer', on ='LocationAbbr')



out_of_ideas
# Out:
#    LocationAbbr Data_Value_x  Data_Value_y Data_Value_x  Data_Value_y
# 0            US         20.4          18.7           27          27.8
# 1            AL         28.2           NaN         33.2          40.9
# 2            AK         18.8          14.7         15.8          17.6
# 3            AZ         19.5          17.3         19.7          24.1
# 4            AR         29.3          32.0         31.2          34.7
# 5            CA         14.2          12.3          NaN           NaN
# 6            CT         11.9          10.2         13.9           NaN
# 7            DE         19.1          18.3         22.2          26.1
# 8            DC         19.1          16.6          NaN          23.9
# 9            FL         20.8          17.5         22.1          26.0
# 10           HI         13.4          11.0         15.8          17.5
# 11           ID         13.5          12.2         15.4          17.9
# ...

# %%
def read_csv(csv_to_read):
    csv_df = pd.read_csv(f'C:\\Users\\AFCummings\\git\\project1\\Resources\\{csv_to_read}')
    csv_df = csv_df[["LocationAbbr", "Data_Value" ]]
    csv_df = csv_df.dropna()
    pd.DataFrame(csv_df)
    dfs.append(csv_df)
    #print(csv_df)

sugar_2017 = read_csv("2017sugar.csv")
header(1) = "2017sugar"
obesity_2017 = read_csv("obesity2017.csv")
sugar_2015 = read_csv('2015sugar.csv')
sugar_2013 = read_csv("2013sugar.csv")
sugar_2011 = read_csv("2011sugar.csv")
sugar_2009 = read_csv("2009sugar.csv")
sugar_2007 = read_csv("2007sugar.csv")
obesity_2015 = read_csv("obesity2015.csv")
obesity_2013 = read_csv("obesity2013.csv")
obesity_2011 = read_csv("obesity2011.csv")
obesity_2009 = read_csv("obesity2009.csv")
obesity_2007 = read_csv("2007obesity.csv")
# Out:
#   File "<ipython-input-56-b0e7e5c77dec>", line 10
#     header(1) = "2017sugar"
#                            ^
# SyntaxError: can't assign to function call

# %%
import pandas as pd
import matplotlib as plt
 
dfs = []

locations = ["C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv",

             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2015sugar.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2013sugar.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2011sugar.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2009sugar.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2007sugar.csv",
            ]
colHdr = ["Sugar2017", "Sugar2015","Sugar2013", "Sugar2011","Sugar2009","Sugar2007"]

i = 0 

while i < 5:
    #print (i)
    #print (locations[i])
    #print (locations[i+1])
    sugar_df_bar = pd.read_csv(locations[i])
    sugar_df2_bar = pd.read_csv(locations[i+1])
    #sugar_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv")
    #obesity_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2017.csv")
    
        
    sugar_df_bar = sugar_df_bar[["LocationAbbr", "Data_Value" ]]
    sugar_df2_bar = sugar_df2_bar[["LocationAbbr", "Data_Value" ]]
    sugar_df_bar = sugar_df_bar.dropna()
    sugar_df2_bar = sugar_df2_bar.dropna()

    if i == 0:
        #Merge obesity data
        improved_df = sugar_df_bar.merge(sugar_df2_bar, how='outer', on ='LocationAbbr')
    else:
        #Merge obesity data
        improved_df = improved_df.merge(sugar_df_bar, how='outer', on ='LocationAbbr')
        improved_df = improved_df.merge(sugar_df2_bar, how='outer', on ='LocationAbbr')
        
        
    #Rename column headers
    improved_df = improved_df.rename(columns={"Data_Value_x":colHdr[i], "Data_Value_y":colHdr[i+1]})
    i = i+2 
improved_df = improved_df.set_index("LocationAbbr")
improved_df
# Out:
#               Sugar2017  Sugar2015 Sugar2013  Sugar2011  Sugar2009  Sugar2007
# LocationAbbr
# US                 18.7       20.4        27       27.8       29.2       33.8
# AK                 14.7       18.8      15.8       17.6       20.1       21.8
# AZ                 17.3       19.5      19.7       24.1       28.1       29.5
# AR                 32.0       29.3      31.2       34.7       33.5       39.4
# CA                 12.3       14.2       NaN        NaN        NaN        NaN
# CT                 10.2       11.9      13.9        NaN        NaN        NaN
# DE                 18.3       19.1      22.2       26.1       28.8       32.4
# DC                 16.6       19.1       NaN       23.9        NaN       30.3
# FL                 17.5       20.8      22.1       26.0       28.6       31.0
# HI                 11.0       13.4      15.8       17.5       20.8       22.6
# ID                 12.2       13.5      15.4       17.9       18.3       23.2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
dfs = []

locations = ["C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2017.csv",

             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2015.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2013.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2011.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2009.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2007.csv"
            ]
colHdr = ["Obesity2017", "Obesity2015", "Obesity2013",
         "Obesity2011","Obesity2009","Obesity2007"]

i = 0 

while i < 5:
    #print (i)
    #print (locations[i])
    #print (locations[i+1])
    obesity_df_bar = pd.read_csv(locations[i])
    obesity_df2_bar = pd.read_csv(locations[i+1])
    #sugar_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv")
    #obesity_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2017.csv")
    
        
    obesity_df_bar = obesity_df_bar[["LocationAbbr", "Data_Value" ]]
    obesity_df2_bar = obesity_df2_bar[["LocationAbbr", "Data_Value" ]]
    obesity_df_bar = obesity_df_bar.dropna()
    obesity_df2_bar = obesity_df2_bar.dropna()

    if i == 0:
        #Merge obesity data
        even_newer_df = obesity_df_bar.merge(obesity_df2_bar, how='outer', on ='LocationAbbr')
    else:
        #Merge obesity data
        even_newer_df = even_newer_df.merge(obesity_df_bar, how='outer', on ='LocationAbbr')
        even_newer_df = even_newer_df.merge(obesity_df2_bar, how='outer', on ='LocationAbbr')
        
        
    #Rename column headers
    even_newer_df = even_newer_df.rename(columns={"Data_Value_x":colHdr[i], "Data_Value_y":colHdr[i+1]})
    i = i+2 
even_newer_df = even_newer_df.set_index("LocationAbbr")    
even_newer_df
# Out:
#               Obesity2017  Obesity2015  Obesity2013  Obesity2011  Obesity2009  \
# LocationAbbr
# US                   14.8         13.9         13.7         13.0         11.8
# AK                   13.7         14.0         12.4         11.5         11.9
# AZ                   12.3         10.9         10.7         10.9         12.8
# AR                   21.7         18.0         17.8         15.2         14.3
# CA                   13.9         13.9          NaN          NaN          NaN
# CO                    9.5          NaN          NaN          7.3          6.9
# CT                   12.7         12.3         12.3         12.5         10.2
# DE                   15.1         15.8         14.2         12.2         13.5
# DC                   16.8         15.1          NaN         14.5          NaN
# FL                   10.9         12.3         11.6         11.5         10.3
# HI                   14.2         12.9         13.4         13.2         14.2
# ...

# %%
import numpy as np
improved_df = improved_df.replace('~','NaN')
even_newer_df = even_newer_df.replace('~','NaN')
improved_df['Sugar2013'] = improved_df['Sugar2013'].astype(float)
means_sugar = np.array(improved_df.mean(axis = 1, skipna= True))
means_obesity = np.array(even_newer_df.mean(axis = 1, skipna= True))
pooooooooop = even_newer_df.mean(axis = 1, skipna= True)
stinky = improved_df.mean(axis = 1, skipna= True)
print(pooooooooop)
print(stinky)
#print(means_obesity)
#print(len(means_obesity))
#print(len(means_sugar))
#print(means_sugar)
# Out:
# LocationAbbr
# US    13.333333
# AK    12.416667
# AZ    11.533333
# AR    16.783333
# CA    13.900000
# CO     7.900000
# CT    12.033333
# DE    14.000000
# DC    15.975000
# FL    11.300000
# HI    13.850000
# ID    10.150000
# IL    12.533333
# IA    13.200000
# KS    11.820000
# KY    17.666667
# LA    15.280000
# ME    12.633333
# MD    12.000000
# MA    10.750000
# MI    13.400000
# MO    14.160000
# MT    10.050000
# NE    12.975000
# NV    11.860000
# NH    11.950000
# NM    13.450000
# NY    11.450000
# NC    13.850000
# ND    12.366667
# OK    15.250000
# PA    13.133333
# RI    11.583333
# SC    15.250000
# TN    17.283333
# TX    15.720000
# UT     7.900000
# VT    11.966667
# VA    12.200000
# WV    16.033333
# WI    11.200000
# GU    21.700000
# PR    11.150000
# AL    15.875000
# IN    13.650000
# MS    17.180000
# SD    10.980000
# WY    10.340000
# GA    13.425000
# NJ     9.966667
# OH    13.333333
# dtype: float64
# LocationAbbr
# US    26.150000
# ...

# %%
improved_more_df = improved_df.take([3, 6, 14, 15, 47, 17, 21, 30, 36, 37], axis = 0)
even_more_newer_df = even_newer_df.take([3, 7, 15, 16, 17, 19, 24, 33, 39, 40], axis = 0)
print(improved_more_df)
print(even_more_newer_df)
# Out:
#               Sugar2017  Sugar2015  Sugar2013  Sugar2011  Sugar2009  Sugar2007
# LocationAbbr
# AR                 32.0       29.3       31.2       34.7       33.5       39.4
# DE                 18.3       19.1       22.2       26.1       28.8       32.4
# KY                 28.1       32.4       32.9       36.4       35.7       40.5
# LA                 28.9        NaN        NaN       40.1       36.6       36.5
# ME                  NaN        NaN        NaN        NaN        NaN       19.9
# MA                 10.5       13.8       14.2       18.3       21.0       24.9
# NV                 15.3       13.7       17.0        NaN       22.1       23.5
# SC                 24.3       26.7       29.2       33.0       33.2       34.3
# WV                 26.2       30.1       38.0       39.1       34.5       45.9
# WI                 15.3        NaN       19.6       23.1       23.1       25.0
#               Obesity2017  Obesity2015  Obesity2013  Obesity2011  Obesity2009  \
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
means_sugar = np.array(improved_more_df.mean(axis = 1, skipna= True))
means_obesity = np.array(even_more_newer_df.mean(axis = 1, skipna= True))
ticks = ['AR', 'DE', 'KY', 'LA', 'ME', 'MA', 'NV', 'SC', 'WV', 'WI']
N = 10
ind = np.arange(N) 
width = 0.35       
plt.bar(ind, means_sugar, width, label='sugar', color='purple')
plt.bar(ind + width, means_obesity, width, label='obesity', color = 'green')
loc = range(len(ticks))
plt.xticks(loc, ticks)
plt.title('% Obesity and % Sugary Drink Consumption Daily per state')
plt.xlabel('State')
plt.ylabel('Percent')
plt.legend(loc='best')
plt.savefig("C:\\Users\\AFCummings\\git\\project1\\Resources\\sugarbar.png")

# %%
import pandas as pd
import matplotlib as plt
 
dfs = []

locations = ["C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2017.csv",

             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2015sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2015.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2013sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2013.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2011sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2011.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2009sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2009.csv",
             
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\2007sugar.csv",
             "C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2007.csv"
            ]
colHdr = ["Sugar2017","Obesity2017","Sugar2015","Obesity2015","Sugar2013","Obesity2013",
         "Sugar2011","Obesity2011","Sugar2009","Obesity2009","Sugar2007","Obesity2007"
         ]

i = 0 

while i < 11:
    #print (i)
    #print (locations[i])
    #print (locations[i+1])
    sugar_df = pd.read_csv(locations[i])
    obesity_df = pd.read_csv(locations[i+1])
    #sugar_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2017sugar.csv")
    #obesity_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2017.csv")
    
        
    sugar_df = sugar_df[["LocationAbbr", "Data_Value" ]]
    obesity_df = obesity_df[["LocationAbbr", "Data_Value" ]]
    obesity_df = obesity_df.dropna()
    sugar_df = sugar_df.dropna()

    if i == 0:
        #Merge obesity data
        new_df = sugar_df.merge(obesity_df, how='outer', on ='LocationAbbr')
    else:
        #Merge obesity data
        new_df = new_df.merge(sugar_df, how='outer', on ='LocationAbbr')
        new_df = new_df.merge(obesity_df, how='outer', on ='LocationAbbr')
        
        
    #Rename column headers
    new_df = new_df.rename(columns={"Data_Value_x":colHdr[i], "Data_Value_y":colHdr[i+1]})
    i = i+2 


#sugar_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\2015sugar.csv")
#obesity_df = pd.read_csv("C:\\Users\\AFCummings\\git\\project1\\Resources\\obesity2015.csv")
#sugar_df = sugar_df[["LocationAbbr", "Data_Value" ]]
#obesity_df = obesity_df[["LocationAbbr", "Data_Value" ]]

#obesity_df = obesity_df.dropna()
#sugar_df = sugar_df.dropna()

#new_df = new_df.merge(sugar_df, how='outer', on ='LocationAbbr')
#new_df = new_df.merge(obesity_df, how='outer', on ='LocationAbbr')

#new_df = new_df.rename(columns={"Data_Value_x":"Sugar2015", "Data_Value_y":"Obesity2015"})


new_df

# %%
new_df['Sugar2013'] = new_df['Sugar2013'].astype(float)
print(new_df.dtypes)
# Out:
# LocationAbbr     object
# Sugar2017       float64
# Obesity2017     float64
# Sugar2015       float64
# Obesity2015     float64
# Sugar2013       float64
# Obesity2013     float64
# Sugar2011       float64
# Obesity2011     float64
# Sugar2009       float64
# Obesity2009     float64
# Sugar2007       float64
# Obesity2007     float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
new_df = new_df.replace('~','NaN')
x = np.array(new_df.loc(axis=1)['Obesity2017', 'Obesity2015', 'Obesity2013', 'Obesity2011', 'Obesity2009', 'Obesity2007'])
y = np.array(new_df.loc(axis=1)['Sugar2017', 'Sugar2015', 'Sugar2013', 'Sugar2011', 'Sugar2009', 'Sugar2007'])
new_df
mask = ~np.isnan(x) & ~np.isnan(y)
#slope, intercept, r_value, p_value, std_err = scipy.stats.mstats.linregress(x,y)
(slope, intercept, _, _, _) = scipy.stats.mstats.linregress(x[mask],y[mask])
fit = slope * x + intercept
fig, ax = plt.subplots()

ax.scatter(x[mask],y[mask])
ax.plot(x, fit, 'b--')
plt.title('% Obese vs % Whom Consume One Sugary Drink Daily')
plt.xlabel('% Obese')
plt.ylabel('% Whom Consume One Sugary Drink Daily')
plt.show()

# %%
print(x)
print(len(x))
# Out:
# [[14.8 13.9 13.7 13.  11.8 12.8]
#  [13.7 14.  12.4 11.5 11.9 11. ]
#  [12.3 10.9 10.7 10.9 12.8 11.6]
#  [21.7 18.  17.8 15.2 14.3 13.7]
#  [13.9 13.9  nan  nan  nan  nan]
#  [12.7 12.3 12.3 12.5 10.2 12.2]
#  [15.1 15.8 14.2 12.2 13.5 13.2]
#  [16.8 15.1  nan 14.5  nan 17.5]
#  [10.9 12.3 11.6 11.5 10.3 11.2]
#  [14.2 12.9 13.4 13.2 14.2 15.2]
#  [11.4 11.1  9.6  9.2  8.7 10.9]
#  [14.8 12.6 11.5 11.6 11.9 12.8]
#  [15.3  nan  nan 13.2  nan 11.1]
#  [13.1  nan 12.6 10.2 12.2 11. ]
#  [20.2 18.5 18.  16.5 17.4 15.4]
#  [17.   nan 13.5 16.1 14.4 15.4]
#  [12.6 11.5 11.  12.  12.  12.9]
#  [11.7 11.  10.2  9.9 10.8 10.9]
#  [16.7 14.3 13.  12.1 11.9 12.4]
#  [11.7 10.3  9.4  8.5 10.3 10.1]
#  [14.6 13.  12.7 11.6  nan  nan]
#  [14.  12.2 11.4  nan 10.9 10.8]
#  [12.8 12.2 11.2 12.1 11.9 11.5]
#  [15.3 15.6 12.6 12.8 13.5 10.9]
#  [12.4 13.1 10.6 11.  10.8 10.8]
#  [15.4 16.4 12.5 12.9 13.2 12.7]
#  [14.9 14.  13.5 11.  10.9  9.9]
#  [17.1 17.3 11.8 16.7 14.  14.6]
# ...

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(y[mask]))
z2 = np.abs(stats.zscore(x[mask]))
#print(z)
print(z2)
print(len(z2))
print(np.where(z2>2))
# Out:
# [0.61361293 0.2834625  0.21009573 0.04668794 0.48688852 0.1200547
#  0.21009573 0.32014588 0.26678823 0.59693867 0.45020514 0.78035558
#  0.30347161 0.81703896 0.89040572 0.81703896 0.1200547  0.56025529
#  3.14476628 1.78748115 1.71411439 0.76034646 0.43019602 0.21009573
#  0.2834625  0.2834625  0.15673809 0.30347161 0.30347161 0.72366308
#  0.98044675 0.39351264 0.34015499 0.13672897 0.02667882 1.34728057
#  0.72366308 0.50356279 1.60406424 0.81703896 0.30347161 0.56025529
#  0.59693867 1.03713925 0.70698881 0.39351264 0.08337132 0.10004559
#  0.02667882 0.39351264 0.76034646 0.63362205 0.74367219 1.29392292
#  1.44065645 1.62407336 0.81703896 0.61361293 0.19342147 0.59693867
#  0.56025529 0.45020514 0.1200547  0.79702984 0.02667882 0.74367219
#  0.01000456 0.19342147 1.07382263 0.34015499 0.78035558 2.59451555
#  1.97089806 1.78748115 1.23723042 1.56738086 0.83371322 1.42064733
#  1.0904969  0.4668794  0.83371322 0.19342147 0.59693867 0.78035558
# ...

# %%
Q1 = new_df.quantile(0.25)
Q3 = new_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
print(new_df < (Q1 - 1.5 * IQR)) |(new_df > (Q3 + 1.5 * IQR))
# Out:
# Sugar2017      4.775
# Obesity2017    4.000
# Sugar2015      7.925
# Obesity2015    3.500
# Sugar2013      7.900
# Obesity2013    2.300
# Sugar2011      5.775
# Obesity2011    3.600
# Sugar2009      9.600
# Obesity2009    2.950
# Sugar2007      9.650
# Obesity2007    2.775
# dtype: float64
#     LocationAbbr  Obesity2007  Obesity2009  Obesity2011  Obesity2013  \
# 0          False        False        False        False        False
# 1          False        False        False        False        False
# 2          False        False        False        False        False
# 3          False        False        False        False        False
# 4          False        False        False        False        False
# 5          False        False        False        False        False
# 6          False        False        False        False        False
# 7          False        False        False        False        False
# ...

# %%
from sklearn.metrics import r2_score
r2_score(x[mask],y[mask])
# Out:
# -23.719060699748667

# %%
uhoh = new_df[~((new_df < (Q1 - 1.5 * IQR)) |(new_df > (Q3 + 1.5 * IQR))).any(axis=1)]
uhoh = uhoh.replace('~', 'NaN')
x = np.array(uhoh.loc(axis=1)['Obesity2017', 'Obesity2015', 'Obesity2013', 'Obesity2011', 'Obesity2009', 'Obesity2007'])
y = np.array(uhoh.loc(axis=1)['Sugar2017', 'Sugar2015', 'Sugar2013', 'Sugar2011', 'Sugar2009', 'Sugar2007'])
mask = ~np.isnan(x) & ~np.isnan(y)
#slope, intercept, r_value, p_value, std_err = scipy.stats.mstats.linregress(x,y)
(slope, intercept, _, _, _) = scipy.stats.mstats.linregress(x[mask],y[mask])
fit = slope * x + intercept
fig, ax = plt.subplots()

ax.scatter(x[mask],y[mask])
ax.plot(x, fit, 'b--')
plt.title('% Obese vs % Whom Consume One Sugary Drink Daily')
plt.xlabel('% Obese')
plt.ylabel('% Whom Consume One Sugary Drink Daily')
plt.show()
plt.savefig("C:\\Users\\AFCummings\\git\\project1\\Resources\\sugarscatter.png")

# %%
from sklearn.metrics import r2_score
r2_score(x[mask],y[mask])
# Out:
# -35.66290302502179
